# %% [markdown]
# ## Set Up and Clean Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import helpers as hp
import models.randomforest as rf
import models.lstm as lstm

# %%
# recent https://forecast.weather.gov/product.php?site=MFL&issuedby=MIA&product=CLI&format=CI&version=2&glossary=0
# Old https://climatecenter.fsu.edu/climate-data-access-tools/downloadable-data


df = pd.read_csv("Data/True values/miami_weather_complete.csv")
df['Datetime'] = pd.to_datetime(df['Datetime'])

# %%
df = df.drop(columns = {"Unnamed: 0", "precipitation",	"mean temp"})
df
# Out:
#       actual_max_temp  min temp   Datetime
# 0                81.0      63.0 2000-01-01
# 1                79.0      66.0 2000-01-02
# 2                80.0      64.0 2000-01-03
# 3                80.0      71.0 2000-01-04
# 4                80.0      67.0 2000-01-05
# ...               ...       ...        ...
# 9089             72.0      55.0 2024-11-23
# 9090             78.0      58.0 2024-11-24
# 9091             82.0      64.0 2024-11-25
# 9092             84.0      67.0 2024-11-26
# 9093             81.0      65.0 2024-11-27
#
# [9094 rows x 3 columns]

# %%
openmeteo = pd.read_csv('Data/MiamiOpenMeteoData.csv')

# %%
openmeteo['time'] = pd.to_datetime(openmeteo['time'], format='%m/%d/%y')

# Convert the datetime column back to the desired string format 'DD/MM/YYYY'
openmeteo['time'] = openmeteo['time'].dt.strftime('%m-%d-%Y')

openmeteo = openmeteo.rename(columns = {"time": "Datetime"})
openmeteo['Datetime'] = pd.to_datetime(openmeteo['Datetime'])
openmeteo.dtypes
# Out:
# Datetime                           datetime64[ns]
# weather_code (wmo code)                     int64
# temperature_2m_max (°F)                   float64
# temperature_2m_min (°F)                   float64
# temperature_2m_mean (°F)                  float64
# apparent_temperature_max (°F)             float64
# apparent_temperature_min (°F)             float64
# apparent_temperature_mean (°F)            float64
# sunrise (iso8601)                          object
# sunset (iso8601)                           object
# daylight_duration (s)                     float64
# sunshine_duration (s)                     float64
# precipitation_sum (mm)                    float64
# rain_sum (mm)                             float64
# snowfall_sum (cm)                         float64
# precipitation_hours (h)                     int64
# wind_speed_10m_max (mp/h)                 float64
# wind_gusts_10m_max (mp/h)                 float64
# wind_direction_10m_dominant (°)           float64
# shortwave_radiation_sum (MJ/m²)           float64
# et0_fao_evapotranspiration (mm)           float64
# dtype: object

# %%
newdf = pd.merge(df,openmeteo, how = "inner", on = "Datetime")

# %%
newdf = newdf.drop(columns = {'sunrise (iso8601)','sunset (iso8601)', 'weather_code (wmo code)'})

# %%
newdf['precipitation_hours (h)'] = newdf['precipitation_hours (h)'].astype(float)
newdf = newdf.set_index("Datetime")

# %%
for col in newdf.columns:
            for lag in range(1,7):
                newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
newdf = newdf.dropna()
new_lstm_df = newdf.copy()
# Out:
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)
# /var/folders/mg/jjtr9hhj5zj6g0svf83l817h0000gn/T/ipykernel_9651/4255776245.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   newdf[f'{col}_lag{lag}'] = newdf[col].shift(lag)

# %% [markdown]
# ## Create training sets

# %%
feature_columns = [
    'actual_max_temp_lag1', 'min temp_lag1', 'temperature_2m_max (°F)_lag1',
    'temperature_2m_min (°F)_lag1', 'temperature_2m_mean (°F)_lag1',
    'daylight_duration (s)_lag1', 'sunshine_duration (s)_lag1', 'precipitation_sum (mm)_lag1',
    'rain_sum (mm)_lag1', 'precipitation_hours (h)_lag1', 'wind_speed_10m_max (mp/h)_lag1',
    'wind_gusts_10m_max (mp/h)_lag1', 'wind_direction_10m_dominant (°)_lag1',
    'shortwave_radiation_sum (MJ/m²)_lag1', 'et0_fao_evapotranspiration (mm)_lag1',
    'apparent_temperature_mean (°F)_lag1', 'apparent_temperature_min (°F)_lag1',
    'apparent_temperature_max (°F)_lag1', 'wind_direction_10m_dominant (°)_lag1'
]

target = 'actual_max_temp'

# %%
rf.find_important_features(newdf, feature_columns, target)
# Out:
#                                  Feature  Importance
# 4          temperature_2m_mean (°F)_lag1    0.396873
# 15   apparent_temperature_mean (°F)_lag1    0.184485
# 16    apparent_temperature_min (°F)_lag1    0.089342
# 17    apparent_temperature_max (°F)_lag1    0.073882
# 0                   actual_max_temp_lag1    0.057896
# 5             daylight_duration (s)_lag1    0.026088
# 12  wind_direction_10m_dominant (°)_lag1    0.021763
# 18  wind_direction_10m_dominant (°)_lag1    0.021612
# 2           temperature_2m_max (°F)_lag1    0.020215
# 13  shortwave_radiation_sum (MJ/m²)_lag1    0.018652
# 10        wind_speed_10m_max (mp/h)_lag1    0.015279
# 11        wind_gusts_10m_max (mp/h)_lag1    0.013909
# 6             sunshine_duration (s)_lag1    0.012358
# 14  et0_fao_evapotranspiration (mm)_lag1    0.010264
# 1                          min temp_lag1    0.009881
# 3           temperature_2m_min (°F)_lag1    0.009847
# 7            precipitation_sum (mm)_lag1    0.006786
# 8                     rain_sum (mm)_lag1    0.006183
# 9           precipitation_hours (h)_lag1    0.004683

# %% [markdown]
# ## Create Train Test sets

# %%
X = newdf[feature_columns]
y = newdf[target]


X_train, y_train, X_test, y_test = hp.create_train_test(X, y, .6)
all_predictions = pd.DataFrame()

# %% [markdown]
# ## Testing the performance of the Random Forest model

# %%
# grid search
best_model = rf.find_best_random_forest_model(X_train, y_train)

# get predictions
predictions = rf.get_rf_predictions(best_model, X_test)

# Calculate errors
hp.calculate_metrics(y_test, predictions)
# Out:
# Best parameters found:  {'bootstrap': True, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Best cross-validation score:  0.8241267627454333
# Mean Squared Error (MSE): 7.494078717145747
# Mean Absolute Error (MAE): 1.9017412159825213
# Root Mean Squared Error (RMSE): 2.7375315006672976
# (7.494078717145747, 2.7375315006672976, 1.9017412159825213)

# %%
rf.plot_predictions(predictions, y_test)
# Out:
# Mean Squared Error (MSE): 7.494078717145747
# Mean Absolute Error (MAE): 1.9017412159825213
# Root Mean Squared Error (RMSE): 2.7375315006672976

# %% [markdown]
# ### Implement LSTM and BiLSTM models

# %%
window = 7
X_windowed, y_windowed, X_test_windowed, y_test_windowed, feature_scaler, target_scaler = lstm.prepare_data(X_train, y_train, X_test, y_test, window_size=window)

lstm_units = 64  
lstm_batch_size = 64
lstm_epochs = 50
lstm_history, LSTM_model_name, trained_lstm_model = lstm.train_LSTM(X_windowed, y_windowed, lstm_units, lstm_batch_size, lstm_epochs, 'best_lstm_checkpoint.keras', verbose=2, learning_rate = .0007)

bl_units = 64  
bl_batch_size = 64
bl_epochs = 50
bilstm_history, biLSTM_model_name, trained_bilstm_model = lstm.train_BiLSTM(X_windowed, y_windowed, bl_units, bl_batch_size, bl_epochs,'best_bilstm_checkpoint.keras', verbose=2, learning_rate = .0005)

# Model summary to check the architecture
trained_bilstm_model.summary()

# Plot loss curves
lstm.plot_loss(lstm_history, LSTM_model_name)
lstm.plot_loss(bilstm_history, biLSTM_model_name)
# Out:
# Epoch 1/50
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 69/69 - 2s - 30ms/step - loss: 0.6435 - val_loss: 0.2418
# Epoch 2/50
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_accuracy available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# 69/69 - 0s - 7ms/step - loss: 0.2919 - val_loss: 0.2249
# Epoch 3/50
# 69/69 - 0s - 6ms/step - loss: 0.2555 - val_loss: 0.2053
# Epoch 4/50
# 69/69 - 0s - 6ms/step - loss: 0.2407 - val_loss: 0.2015
# Epoch 5/50
# 69/69 - 0s - 6ms/step - loss: 0.2307 - val_loss: 0.2015
# Epoch 6/50
# 69/69 - 0s - 6ms/step - loss: 0.2350 - val_loss: 0.1942
# Epoch 7/50
# 69/69 - 0s - 6ms/step - loss: 0.2274 - val_loss: 0.1906
# Epoch 8/50
# 69/69 - 0s - 6ms/step - loss: 0.2175 - val_loss: 0.1906
# Epoch 9/50
# 69/69 - 0s - 6ms/step - loss: 0.2187 - val_loss: 0.1887
# Epoch 10/50
# 69/69 - 0s - 6ms/step - loss: 0.2166 - val_loss: 0.1892
# Epoch 11/50
# 69/69 - 0s - 6ms/step - loss: 0.2050 - val_loss: 0.1901
# Epoch 12/50
# 69/69 - 0s - 7ms/step - loss: 0.2038 - val_loss: 0.1897
# Epoch 13/50
# 69/69 - 0s - 6ms/step - loss: 0.2028 - val_loss: 0.1858
# Epoch 14/50
# 69/69 - 0s - 6ms/step - loss: 0.1956 - val_loss: 0.1857
# Epoch 15/50
# 69/69 - 0s - 6ms/step - loss: 0.1994 - val_loss: 0.1851
# Epoch 16/50
# 69/69 - 0s - 6ms/step - loss: 0.1877 - val_loss: 0.1890
# Epoch 17/50
# 69/69 - 0s - 6ms/step - loss: 0.1860 - val_loss: 0.1910
# Epoch 18/50
# 69/69 - 1s - 7ms/step - loss: 0.1885 - val_loss: 0.1927
# Epoch 19/50
# 69/69 - 0s - 7ms/step - loss: 0.1792 - val_loss: 0.1962
# Epoch 20/50
# 69/69 - 0s - 6ms/step - loss: 0.1747 - val_loss: 0.1977
# Epoch 21/50
# 69/69 - 0s - 6ms/step - loss: 0.1661 - val_loss: 0.2020
# Epoch 22/50
# 69/69 - 0s - 6ms/step - loss: 0.1650 - val_loss: 0.2035
# Epoch 23/50
# 69/69 - 0s - 6ms/step - loss: 0.1652 - val_loss: 0.2021
# Epoch 24/50
# 69/69 - 0s - 6ms/step - loss: 0.1629 - val_loss: 0.2122
# Epoch 25/50
# 69/69 - 0s - 6ms/step - loss: 0.1618 - val_loss: 0.2143
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from -inf to 0.00000, saving model to best_bilstm_checkpoint.keras
# 69/69 - 4s - 60ms/step - accuracy: 0.0000e+00 - loss: 0.7964 - val_accuracy: 0.0000e+00 - val_loss: 0.5627
# Epoch 2/50
#
# Epoch 2: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 8ms/step - accuracy: 0.0000e+00 - loss: 0.4919 - val_accuracy: 0.0000e+00 - val_loss: 0.3479
# Epoch 3/50
#
# Epoch 3: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.3707 - val_accuracy: 0.0000e+00 - val_loss: 0.2927
# Epoch 4/50
#
# Epoch 4: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.3328 - val_accuracy: 0.0000e+00 - val_loss: 0.2645
# Epoch 5/50
#
# Epoch 5: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.2971 - val_accuracy: 0.0000e+00 - val_loss: 0.2466
# Epoch 6/50
#
# Epoch 6: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.2717 - val_accuracy: 0.0000e+00 - val_loss: 0.2257
# Epoch 7/50
#
# Epoch 7: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.2526 - val_accuracy: 0.0000e+00 - val_loss: 0.2151
# Epoch 8/50
#
# Epoch 8: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.2417 - val_accuracy: 0.0000e+00 - val_loss: 0.2080
# Epoch 9/50
#
# Epoch 9: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 10ms/step - accuracy: 0.0000e+00 - loss: 0.2375 - val_accuracy: 0.0000e+00 - val_loss: 0.2020
# Epoch 10/50
#
# Epoch 10: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.2280 - val_accuracy: 0.0000e+00 - val_loss: 0.2012
# Epoch 11/50
#
# Epoch 11: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 10ms/step - accuracy: 0.0000e+00 - loss: 0.2207 - val_accuracy: 0.0000e+00 - val_loss: 0.1996
# Epoch 12/50
#
# Epoch 12: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.2193 - val_accuracy: 0.0000e+00 - val_loss: 0.1956
# Epoch 13/50
#
# Epoch 13: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.2147 - val_accuracy: 0.0000e+00 - val_loss: 0.1963
# Epoch 14/50
#
# Epoch 14: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.2147 - val_accuracy: 0.0000e+00 - val_loss: 0.1928
# Epoch 15/50
#
# Epoch 15: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.2131 - val_accuracy: 0.0000e+00 - val_loss: 0.1986
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.2007 - val_accuracy: 0.0000e+00 - val_loss: 0.1949
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.1983 - val_accuracy: 0.0000e+00 - val_loss: 0.1932
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.1991 - val_accuracy: 0.0000e+00 - val_loss: 0.1932
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.1905 - val_accuracy: 0.0000e+00 - val_loss: 0.1914
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.1960 - val_accuracy: 0.0000e+00 - val_loss: 0.1916
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.1889 - val_accuracy: 0.0000e+00 - val_loss: 0.1942
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.1913 - val_accuracy: 0.0000e+00 - val_loss: 0.1984
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.1896 - val_accuracy: 0.0000e+00 - val_loss: 0.1940
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.1789 - val_accuracy: 0.0000e+00 - val_loss: 0.1924
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.1809 - val_accuracy: 0.0000e+00 - val_loss: 0.2034
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.1808 - val_accuracy: 0.0000e+00 - val_loss: 0.2057
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.1852 - val_accuracy: 0.0000e+00 - val_loss: 0.1946
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 9ms/step - accuracy: 0.0000e+00 - loss: 0.1728 - val_accuracy: 0.0000e+00 - val_loss: 0.1932
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.00000
# 69/69 - 1s - 10ms/step - accuracy: 0.0000e+00 - loss: 0.1772 - val_accuracy: 0.0000e+00 - val_loss: 0.1953
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 7, 60)          │        12,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 7, 40)          │        12,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 20)             │         4,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 97,493 (380.84 KB)
#  Trainable params: 32,497 (126.94 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 64,996 (253.89 KB)

# %%
bilstm_y_pred = lstm.get_predictions(trained_bilstm_model, X_test_windowed)

lstm.plot_predictions(biLSTM_model_name, X_test_windowed, y_test_windowed, bilstm_y_pred, target_scaler)
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Mean Squared Error (MSE): 8.61094059064055
# Mean Absolute Error (MAE): 2.05925286348201
# Root Mean Squared Error (RMSE): 2.9344404220635574

# %%
lstm_y_pred = lstm.get_predictions(trained_lstm_model, X_test_windowed)
lstm.plot_predictions(LSTM_model_name, X_test_windowed, y_test_windowed, lstm_y_pred, target_scaler)
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean Squared Error (MSE): 9.35865907595439
# Mean Absolute Error (MAE): 2.1898246523434137
# Root Mean Squared Error (RMSE): 3.059192552938502

# %%
missing = window - 1
y_actual_test = y_test.iloc[missing:] #removes the first two observations since those are removed in the sliding window process.
rf_predictions = predictions[missing:]
predictions_df = pd.DataFrame(y_actual_test)
predictions_df['lstm_predictions'] = lstm_y_pred
predictions_df['bilstm_predictions'] = bilstm_y_pred
predictions_df['rf_predictions'] = rf_predictions

open_meteo_forecast = pd.read_csv("/Users/bram/Desktop/AI-class/semester-project-bram-long/Data/OpenMeteoMiamiForecast.csv")
open_meteo_forecast ['time'] = pd.to_datetime(open_meteo_forecast ['time'], format='%m/%d/%y')
open_meteo_forecast = open_meteo_forecast.set_index("time")
open_meteo_forecast = open_meteo_forecast.rename(columns={"temperature_2m_max (°F)":"open_meteo_forecast"})

prediction_merge = pd.merge(open_meteo_forecast, predictions_df, left_index=True, right_index=True)

# %%
actual = prediction_merge['actual_max_temp']
open_predicted = prediction_merge['open_meteo_forecast']


lstm_predictions_np = prediction_merge['lstm_predictions'].to_numpy()
lstm_predictions_np = target_scaler.inverse_transform(lstm_predictions_np.reshape(-1, 1))

bilstm_predictions_np = prediction_merge['bilstm_predictions'].to_numpy()
bilstm_predictions_np = target_scaler.inverse_transform(bilstm_predictions_np.reshape(-1, 1))


rf_metrics = hp.calculate_metrics(actual, prediction_merge['rf_predictions'])
lstm_metrics = hp.calculate_metrics(actual, lstm_predictions_np)
bilstm_metrics = hp.calculate_metrics(actual, bilstm_predictions_np)
open_metrics = hp.calculate_metrics(actual, open_predicted)
# Out:
# Mean Squared Error (MSE): 8.082738383230897
# Mean Absolute Error (MAE): 2.0164076410381515
# Root Mean Squared Error (RMSE): 2.843015719835347
# Mean Squared Error (MSE): 9.82478848061924
# Mean Absolute Error (MAE): 2.300366751866858
# Root Mean Squared Error (RMSE): 3.1344518628652187
# Mean Squared Error (MSE): 9.22985966486346
# Mean Absolute Error (MAE): 2.174372173071458
# Root Mean Squared Error (RMSE): 3.038068410168451
# Mean Squared Error (MSE): 4.117020785219398
# Mean Absolute Error (MAE): 1.6639722863741335
# Root Mean Squared Error (RMSE): 2.029044303414639

# %%
y_ensemble = prediction_merge['actual_max_temp']

X_ensemble = prediction_merge[['open_meteo_forecast', 'lstm_predictions',
       'bilstm_predictions', 'rf_predictions']]
 
X_ensemble_train, y_ensemble_train, X_ensemble_test, y_ensemble_test = hp.create_train_test(X_ensemble ,y_ensemble, .7)

ensemble_X_windowed, ensemble_y_windowed, ensemble_X_test_windowed, ensemble_y_test_windowed, ensemble_feature_scaler, ensemble_target_scaler = lstm.prepare_data(X_ensemble_train, y_ensemble_train, X_ensemble_test, y_ensemble_test, window_size=7)

lstm_units = 64  
lstm_batch_size = 64
lstm_epochs = 300
ensemble_lstm_history, ensemble_LSTM_model_name, ensemble_trained_lstm_model = lstm.train_LSTM(ensemble_X_windowed, ensemble_y_windowed, lstm_units, lstm_batch_size, lstm_epochs, 'ensemble_lstm_checkpoint.keras', verbose=2, learning_rate = .0007)

bl_units = 64  
bl_batch_size = 64
bl_epochs = 300
ensemble_bilstm_history, ensemble_biLSTM_model_name, ensemble_trained_bilstm_model = lstm.train_BiLSTM(ensemble_X_windowed, ensemble_y_windowed, bl_units, bl_batch_size, bl_epochs, 'ensemble_bilstm_checkpoint.keras', verbose=2, learning_rate = .0005)
# Out:
# Epoch 1/300
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 - 1s - 357ms/step - loss: 0.9804 - val_loss: 1.1055
# Epoch 2/300
# 4/4 - 0s - 11ms/step - loss: 0.9695 - val_loss: 1.0921
# Epoch 3/300
# 4/4 - 0s - 10ms/step - loss: 0.9574 - val_loss: 1.0715
# Epoch 4/300
# 4/4 - 0s - 11ms/step - loss: 0.9497 - val_loss: 1.0408
# Epoch 5/300
# 4/4 - 0s - 11ms/step - loss: 0.9151 - val_loss: 0.9990
# Epoch 6/300
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_accuracy available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# 4/4 - 0s - 11ms/step - loss: 0.8725 - val_loss: 0.9230
# Epoch 7/300
# 4/4 - 0s - 11ms/step - loss: 0.8146 - val_loss: 0.8045
# Epoch 8/300
# 4/4 - 0s - 10ms/step - loss: 0.6773 - val_loss: 0.6247
# Epoch 9/300
# 4/4 - 0s - 10ms/step - loss: 0.4966 - val_loss: 0.4743
# Epoch 10/300
# 4/4 - 0s - 10ms/step - loss: 0.4820 - val_loss: 0.3830
# Epoch 11/300
# 4/4 - 0s - 10ms/step - loss: 0.4043 - val_loss: 0.3597
# Epoch 12/300
# 4/4 - 0s - 10ms/step - loss: 0.3445 - val_loss: 0.3272
# Epoch 13/300
# 4/4 - 0s - 10ms/step - loss: 0.3079 - val_loss: 0.3085
# Epoch 14/300
# 4/4 - 0s - 10ms/step - loss: 0.2948 - val_loss: 0.3002
# Epoch 15/300
# 4/4 - 0s - 10ms/step - loss: 0.2781 - val_loss: 0.2644
# Epoch 16/300
# 4/4 - 0s - 10ms/step - loss: 0.2443 - val_loss: 0.2430
# Epoch 17/300
# 4/4 - 0s - 10ms/step - loss: 0.2303 - val_loss: 0.2205
# Epoch 18/300
# 4/4 - 0s - 11ms/step - loss: 0.2046 - val_loss: 0.1970
# Epoch 19/300
# 4/4 - 0s - 10ms/step - loss: 0.2348 - val_loss: 0.1891
# Epoch 20/300
# 4/4 - 0s - 10ms/step - loss: 0.2032 - val_loss: 0.1718
# Epoch 21/300
# 4/4 - 0s - 11ms/step - loss: 0.1856 - val_loss: 0.1571
# Epoch 22/300
# 4/4 - 0s - 11ms/step - loss: 0.1700 - val_loss: 0.1493
# Epoch 23/300
# 4/4 - 0s - 10ms/step - loss: 0.1721 - val_loss: 0.1384
# Epoch 24/300
# 4/4 - 0s - 10ms/step - loss: 0.1596 - val_loss: 0.1269
# Epoch 25/300
# 4/4 - 0s - 10ms/step - loss: 0.1475 - val_loss: 0.1019
# Epoch 26/300
# 4/4 - 0s - 10ms/step - loss: 0.1223 - val_loss: 0.0969
# Epoch 27/300
# 4/4 - 0s - 10ms/step - loss: 0.1221 - val_loss: 0.0811
# Epoch 28/300
# 4/4 - 0s - 10ms/step - loss: 0.1419 - val_loss: 0.0809
# Epoch 29/300
# 4/4 - 0s - 10ms/step - loss: 0.1208 - val_loss: 0.0802
# Epoch 30/300
# 4/4 - 0s - 10ms/step - loss: 0.1257 - val_loss: 0.0656
# Epoch 31/300
# 4/4 - 0s - 10ms/step - loss: 0.1182 - val_loss: 0.0648
# Epoch 32/300
# 4/4 - 0s - 10ms/step - loss: 0.1004 - val_loss: 0.0847
# Epoch 33/300
# 4/4 - 0s - 10ms/step - loss: 0.1280 - val_loss: 0.0588
# Epoch 34/300
# 4/4 - 0s - 10ms/step - loss: 0.1064 - val_loss: 0.0573
# Epoch 35/300
# 4/4 - 0s - 10ms/step - loss: 0.0981 - val_loss: 0.0588
# Epoch 36/300
# 4/4 - 0s - 11ms/step - loss: 0.0910 - val_loss: 0.0632
# Epoch 37/300
# 4/4 - 0s - 10ms/step - loss: 0.1031 - val_loss: 0.0501
# Epoch 38/300
# 4/4 - 0s - 10ms/step - loss: 0.0740 - val_loss: 0.0457
# Epoch 39/300
# 4/4 - 0s - 11ms/step - loss: 0.0890 - val_loss: 0.0453
# Epoch 40/300
# 4/4 - 0s - 11ms/step - loss: 0.0855 - val_loss: 0.0632
# Epoch 41/300
# 4/4 - 0s - 11ms/step - loss: 0.0972 - val_loss: 0.0481
# Epoch 42/300
# 4/4 - 0s - 10ms/step - loss: 0.0897 - val_loss: 0.0505
# Epoch 43/300
# 4/4 - 0s - 10ms/step - loss: 0.0795 - val_loss: 0.0493
# Epoch 44/300
# 4/4 - 0s - 11ms/step - loss: 0.0900 - val_loss: 0.0570
# Epoch 45/300
# 4/4 - 0s - 13ms/step - loss: 0.0774 - val_loss: 0.0507
# Epoch 46/300
# 4/4 - 0s - 11ms/step - loss: 0.0886 - val_loss: 0.0514
# Epoch 47/300
# 4/4 - 0s - 10ms/step - loss: 0.0860 - val_loss: 0.0444
# Epoch 48/300
# 4/4 - 0s - 10ms/step - loss: 0.0664 - val_loss: 0.0477
# Epoch 49/300
# 4/4 - 0s - 10ms/step - loss: 0.0723 - val_loss: 0.0421
# Epoch 50/300
# 4/4 - 0s - 10ms/step - loss: 0.0842 - val_loss: 0.0712
# Epoch 51/300
# 4/4 - 0s - 12ms/step - loss: 0.1203 - val_loss: 0.0593
# Epoch 52/300
# 4/4 - 0s - 11ms/step - loss: 0.0609 - val_loss: 0.0548
# Epoch 53/300
# 4/4 - 0s - 11ms/step - loss: 0.0686 - val_loss: 0.0520
# Epoch 54/300
# 4/4 - 0s - 11ms/step - loss: 0.0629 - val_loss: 0.0575
# Epoch 55/300
# 4/4 - 0s - 11ms/step - loss: 0.0778 - val_loss: 0.0457
# Epoch 56/300
# 4/4 - 0s - 10ms/step - loss: 0.0632 - val_loss: 0.0575
# Epoch 57/300
# 4/4 - 0s - 10ms/step - loss: 0.0934 - val_loss: 0.0568
# Epoch 58/300
# 4/4 - 0s - 10ms/step - loss: 0.0801 - val_loss: 0.0705
# Epoch 59/300
# 4/4 - 0s - 10ms/step - loss: 0.0976 - val_loss: 0.0457
# Epoch 1/300
#
# Epoch 1: val_accuracy improved from -inf to 0.00000, saving model to ensemble_bilstm_checkpoint.keras
# 4/4 - 4s - 926ms/step - accuracy: 0.0000e+00 - loss: 0.9816 - val_accuracy: 0.0000e+00 - val_loss: 1.0994
# Epoch 2/300
#
# Epoch 2: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 12ms/step - accuracy: 0.0000e+00 - loss: 0.9703 - val_accuracy: 0.0000e+00 - val_loss: 1.0862
# Epoch 3/300
#
# Epoch 3: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 12ms/step - accuracy: 0.0000e+00 - loss: 0.9571 - val_accuracy: 0.0000e+00 - val_loss: 1.0696
# Epoch 4/300
#
# Epoch 4: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 12ms/step - accuracy: 0.0000e+00 - loss: 0.9358 - val_accuracy: 0.0000e+00 - val_loss: 1.0494
# Epoch 5/300
#
# Epoch 5: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.9271 - val_accuracy: 0.0000e+00 - val_loss: 1.0252
# Epoch 6/300
#
# Epoch 6: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.9013 - val_accuracy: 0.0000e+00 - val_loss: 0.9959
# Epoch 7/300
#
# Epoch 7: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 12ms/step - accuracy: 0.0000e+00 - loss: 0.8801 - val_accuracy: 0.0000e+00 - val_loss: 0.9605
# Epoch 8/300
#
# Epoch 8: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.8436 - val_accuracy: 0.0000e+00 - val_loss: 0.9176
# Epoch 9/300
#
# Epoch 9: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.7887 - val_accuracy: 0.0000e+00 - val_loss: 0.8659
# Epoch 10/300
#
# Epoch 10: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.7518 - val_accuracy: 0.0000e+00 - val_loss: 0.8083
# Epoch 11/300
#
# Epoch 11: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.7016 - val_accuracy: 0.0000e+00 - val_loss: 0.7495
# Epoch 12/300
#
# Epoch 12: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.6609 - val_accuracy: 0.0000e+00 - val_loss: 0.6929
# Epoch 13/300
#
# Epoch 13: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 12ms/step - accuracy: 0.0000e+00 - loss: 0.6170 - val_accuracy: 0.0000e+00 - val_loss: 0.6448
# Epoch 14/300
#
# Epoch 14: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.5648 - val_accuracy: 0.0000e+00 - val_loss: 0.6075
# Epoch 15/300
#
# Epoch 15: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 12ms/step - accuracy: 0.0000e+00 - loss: 0.5195 - val_accuracy: 0.0000e+00 - val_loss: 0.5747
# Epoch 16/300
#
# Epoch 16: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.4844 - val_accuracy: 0.0000e+00 - val_loss: 0.5497
# Epoch 17/300
#
# Epoch 17: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.4839 - val_accuracy: 0.0000e+00 - val_loss: 0.5309
# Epoch 18/300
#
# Epoch 18: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.4801 - val_accuracy: 0.0000e+00 - val_loss: 0.5108
# Epoch 19/300
#
# Epoch 19: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.4308 - val_accuracy: 0.0000e+00 - val_loss: 0.4788
# Epoch 20/300
#
# Epoch 20: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.4119 - val_accuracy: 0.0000e+00 - val_loss: 0.4596
# Epoch 21/300
#
# Epoch 21: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.4001 - val_accuracy: 0.0000e+00 - val_loss: 0.4319
# Epoch 22/300
#
# Epoch 22: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 11ms/step - accuracy: 0.0000e+00 - loss: 0.3634 - val_accuracy: 0.0000e+00 - val_loss: 0.4101
# Epoch 23/300
#
# Epoch 23: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 12ms/step - accuracy: 0.0000e+00 - loss: 0.3583 - val_accuracy: 0.0000e+00 - val_loss: 0.3903
# Epoch 24/300
#
# Epoch 24: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.3493 - val_accuracy: 0.0000e+00 - val_loss: 0.3720
# Epoch 25/300
#
# Epoch 25: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.3496 - val_accuracy: 0.0000e+00 - val_loss: 0.3511
# Epoch 26/300
#
# Epoch 26: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.3251 - val_accuracy: 0.0000e+00 - val_loss: 0.3485
# Epoch 27/300
#
# Epoch 27: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.3048 - val_accuracy: 0.0000e+00 - val_loss: 0.3469
# Epoch 28/300
#
# Epoch 28: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.2704 - val_accuracy: 0.0000e+00 - val_loss: 0.3164
# Epoch 29/300
#
# Epoch 29: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.2607 - val_accuracy: 0.0000e+00 - val_loss: 0.3233
# Epoch 30/300
#
# Epoch 30: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.2266 - val_accuracy: 0.0000e+00 - val_loss: 0.3295
# Epoch 31/300
#
# Epoch 31: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.2532 - val_accuracy: 0.0000e+00 - val_loss: 0.2883
# Epoch 32/300
#
# Epoch 32: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.2546 - val_accuracy: 0.0000e+00 - val_loss: 0.3285
# Epoch 33/300
#
# Epoch 33: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 15ms/step - accuracy: 0.0000e+00 - loss: 0.2291 - val_accuracy: 0.0000e+00 - val_loss: 0.3123
# Epoch 34/300
#
# Epoch 34: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.2337 - val_accuracy: 0.0000e+00 - val_loss: 0.2448
# Epoch 35/300
#
# Epoch 35: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.2375 - val_accuracy: 0.0000e+00 - val_loss: 0.2550
# Epoch 36/300
#
# Epoch 36: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1905 - val_accuracy: 0.0000e+00 - val_loss: 0.2653
# Epoch 37/300
#
# Epoch 37: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.2313 - val_accuracy: 0.0000e+00 - val_loss: 0.2320
# Epoch 38/300
#
# Epoch 38: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1792 - val_accuracy: 0.0000e+00 - val_loss: 0.2390
# Epoch 39/300
#
# Epoch 39: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1806 - val_accuracy: 0.0000e+00 - val_loss: 0.2223
# Epoch 40/300
#
# Epoch 40: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.2016 - val_accuracy: 0.0000e+00 - val_loss: 0.2164
# Epoch 41/300
#
# Epoch 41: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1834 - val_accuracy: 0.0000e+00 - val_loss: 0.2361
# Epoch 42/300
#
# Epoch 42: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1854 - val_accuracy: 0.0000e+00 - val_loss: 0.1998
# Epoch 43/300
#
# Epoch 43: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1835 - val_accuracy: 0.0000e+00 - val_loss: 0.1982
# Epoch 44/300
#
# Epoch 44: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1650 - val_accuracy: 0.0000e+00 - val_loss: 0.2144
# Epoch 45/300
#
# Epoch 45: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1685 - val_accuracy: 0.0000e+00 - val_loss: 0.2185
# Epoch 46/300
#
# Epoch 46: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1527 - val_accuracy: 0.0000e+00 - val_loss: 0.1832
# Epoch 47/300
#
# Epoch 47: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1579 - val_accuracy: 0.0000e+00 - val_loss: 0.1973
# Epoch 48/300
#
# Epoch 48: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1579 - val_accuracy: 0.0000e+00 - val_loss: 0.2034
# Epoch 49/300
#
# Epoch 49: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1404 - val_accuracy: 0.0000e+00 - val_loss: 0.1952
# Epoch 50/300
#
# Epoch 50: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1598 - val_accuracy: 0.0000e+00 - val_loss: 0.2065
# Epoch 51/300
#
# Epoch 51: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1281 - val_accuracy: 0.0000e+00 - val_loss: 0.1885
# Epoch 52/300
#
# Epoch 52: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1292 - val_accuracy: 0.0000e+00 - val_loss: 0.1624
# Epoch 53/300
#
# Epoch 53: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1422 - val_accuracy: 0.0000e+00 - val_loss: 0.1761
# Epoch 54/300
#
# Epoch 54: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1364 - val_accuracy: 0.0000e+00 - val_loss: 0.1867
# Epoch 55/300
#
# Epoch 55: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1526 - val_accuracy: 0.0000e+00 - val_loss: 0.1551
# Epoch 56/300
#
# Epoch 56: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1331 - val_accuracy: 0.0000e+00 - val_loss: 0.1500
# Epoch 57/300
#
# Epoch 57: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1431 - val_accuracy: 0.0000e+00 - val_loss: 0.1423
# Epoch 58/300
#
# Epoch 58: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1374 - val_accuracy: 0.0000e+00 - val_loss: 0.1686
# Epoch 59/300
#
# Epoch 59: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1333 - val_accuracy: 0.0000e+00 - val_loss: 0.1394
# Epoch 60/300
#
# Epoch 60: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1252 - val_accuracy: 0.0000e+00 - val_loss: 0.1495
# Epoch 61/300
#
# Epoch 61: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1273 - val_accuracy: 0.0000e+00 - val_loss: 0.1398
# Epoch 62/300
#
# Epoch 62: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1069 - val_accuracy: 0.0000e+00 - val_loss: 0.1312
# Epoch 63/300
#
# Epoch 63: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.0984 - val_accuracy: 0.0000e+00 - val_loss: 0.1468
# Epoch 64/300
#
# Epoch 64: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1013 - val_accuracy: 0.0000e+00 - val_loss: 0.1333
# Epoch 65/300
#
# Epoch 65: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1153 - val_accuracy: 0.0000e+00 - val_loss: 0.1261
# Epoch 66/300
#
# Epoch 66: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.0947 - val_accuracy: 0.0000e+00 - val_loss: 0.1578
# Epoch 67/300
#
# Epoch 67: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1024 - val_accuracy: 0.0000e+00 - val_loss: 0.1249
# Epoch 68/300
#
# Epoch 68: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1414 - val_accuracy: 0.0000e+00 - val_loss: 0.1148
# Epoch 69/300
#
# Epoch 69: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.0947 - val_accuracy: 0.0000e+00 - val_loss: 0.1431
# Epoch 70/300
#
# Epoch 70: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0877 - val_accuracy: 0.0000e+00 - val_loss: 0.1090
# Epoch 71/300
#
# Epoch 71: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.0980 - val_accuracy: 0.0000e+00 - val_loss: 0.1136
# Epoch 72/300
#
# Epoch 72: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1001 - val_accuracy: 0.0000e+00 - val_loss: 0.1365
# Epoch 73/300
#
# Epoch 73: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1004 - val_accuracy: 0.0000e+00 - val_loss: 0.1086
# Epoch 74/300
#
# Epoch 74: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0964 - val_accuracy: 0.0000e+00 - val_loss: 0.1018
# Epoch 75/300
#
# Epoch 75: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 15ms/step - accuracy: 0.0000e+00 - loss: 0.1027 - val_accuracy: 0.0000e+00 - val_loss: 0.0992
# Epoch 76/300
#
# Epoch 76: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1020 - val_accuracy: 0.0000e+00 - val_loss: 0.1035
# Epoch 77/300
#
# Epoch 77: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.0948 - val_accuracy: 0.0000e+00 - val_loss: 0.1008
# Epoch 78/300
#
# Epoch 78: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.1010 - val_accuracy: 0.0000e+00 - val_loss: 0.1128
# Epoch 79/300
#
# Epoch 79: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1149 - val_accuracy: 0.0000e+00 - val_loss: 0.0942
# Epoch 80/300
#
# Epoch 80: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.0957 - val_accuracy: 0.0000e+00 - val_loss: 0.1131
# Epoch 81/300
#
# Epoch 81: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0884 - val_accuracy: 0.0000e+00 - val_loss: 0.1147
# Epoch 82/300
#
# Epoch 82: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0759 - val_accuracy: 0.0000e+00 - val_loss: 0.0839
# Epoch 83/300
#
# Epoch 83: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0905 - val_accuracy: 0.0000e+00 - val_loss: 0.0988
# Epoch 84/300
#
# Epoch 84: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.0868 - val_accuracy: 0.0000e+00 - val_loss: 0.1041
# Epoch 85/300
#
# Epoch 85: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.0760 - val_accuracy: 0.0000e+00 - val_loss: 0.0738
# Epoch 86/300
#
# Epoch 86: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0745 - val_accuracy: 0.0000e+00 - val_loss: 0.0803
# Epoch 87/300
#
# Epoch 87: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0810 - val_accuracy: 0.0000e+00 - val_loss: 0.0880
# Epoch 88/300
#
# Epoch 88: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0954 - val_accuracy: 0.0000e+00 - val_loss: 0.0761
# Epoch 89/300
#
# Epoch 89: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.1048 - val_accuracy: 0.0000e+00 - val_loss: 0.0688
# Epoch 90/300
#
# Epoch 90: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0750 - val_accuracy: 0.0000e+00 - val_loss: 0.0893
# Epoch 91/300
#
# Epoch 91: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0855 - val_accuracy: 0.0000e+00 - val_loss: 0.0665
# Epoch 92/300
#
# Epoch 92: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0765 - val_accuracy: 0.0000e+00 - val_loss: 0.0795
# Epoch 93/300
#
# Epoch 93: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.0754 - val_accuracy: 0.0000e+00 - val_loss: 0.0745
# Epoch 94/300
#
# Epoch 94: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.0792 - val_accuracy: 0.0000e+00 - val_loss: 0.0869
# Epoch 95/300
#
# Epoch 95: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0733 - val_accuracy: 0.0000e+00 - val_loss: 0.0890
# Epoch 96/300
#
# Epoch 96: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0699 - val_accuracy: 0.0000e+00 - val_loss: 0.0792
# Epoch 97/300
#
# Epoch 97: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0761 - val_accuracy: 0.0000e+00 - val_loss: 0.0905
# Epoch 98/300
#
# Epoch 98: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0792 - val_accuracy: 0.0000e+00 - val_loss: 0.0773
# Epoch 99/300
#
# Epoch 99: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 14ms/step - accuracy: 0.0000e+00 - loss: 0.0699 - val_accuracy: 0.0000e+00 - val_loss: 0.0787
# Epoch 100/300
#
# Epoch 100: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.0949 - val_accuracy: 0.0000e+00 - val_loss: 0.0807
# Epoch 101/300
#
# Epoch 101: val_accuracy did not improve from 0.00000
# 4/4 - 0s - 13ms/step - accuracy: 0.0000e+00 - loss: 0.0609 - val_accuracy: 0.0000e+00 - val_loss: 0.0710

# %%
ensemble_trained_lstm_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_10 (LSTM)                  │ (None, 7, 64)          │        17,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 174,053 (679.90 KB)
#  Trainable params: 58,017 (226.63 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 116,036 (453.27 KB)

# %%
lstm.plot_loss(ensemble_lstm_history, ensemble_LSTM_model_name)
lstm.plot_loss(ensemble_bilstm_history, ensemble_biLSTM_model_name)

# %%
ensemble_lstm_y_pred = lstm.get_predictions(ensemble_trained_lstm_model, ensemble_X_test_windowed)

lstm.plot_predictions('Ensemble LSTM', ensemble_X_test_windowed, ensemble_y_test_windowed, ensemble_lstm_y_pred, ensemble_target_scaler)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error (MSE): 2.0592018045835205
# Mean Absolute Error (MAE): 1.1138350579046434
# Root Mean Squared Error (RMSE): 1.4349919179505928

# %%
ensemble_bilstm_y_pred = lstm.get_predictions(ensemble_trained_bilstm_model, ensemble_X_test_windowed)

lstm.plot_predictions('Ensemble BiLSTM', ensemble_X_test_windowed, ensemble_y_test_windowed, ensemble_bilstm_y_pred, ensemble_target_scaler)


# print(target_scaler.inverse_transform(ensemble_y_test_windowed))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error (MSE): 2.4946938481030707
# Mean Absolute Error (MAE): 1.2022987488777406
# Root Mean Squared Error (RMSE): 1.5794599862304428

# %%
# grid search
ensemble_rf_best_model = rf.find_best_random_forest_model(X_ensemble_train, y_ensemble_train)

# get predictions
ensemble_rf_predictions = rf.get_rf_predictions(ensemble_rf_best_model, X_ensemble_test)

hp.calculate_metrics(y_ensemble_test, ensemble_rf_predictions)
# Out:
# Best parameters found:  {'bootstrap': True, 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Best cross-validation score:  0.9442597449806831
# Mean Squared Error (MSE): 1.7335980469656695
# Mean Absolute Error (MAE): 1.0287669108669106
# Root Mean Squared Error (RMSE): 1.316661705589431
# (1.7335980469656695, 1.316661705589431, 1.0287669108669106)

# %%
rf.plot_predictions(ensemble_rf_predictions, y_ensemble_test)
# Out:
# Mean Squared Error (MSE): 1.7335980469656695
# Mean Absolute Error (MAE): 1.0287669108669106
# Root Mean Squared Error (RMSE): 1.316661705589431
# 2024-11-06    86.0
# 2022-06-27    90.0
# 2023-02-04    75.0
# 2022-03-18    85.0
# 2024-07-06    91.0
#               ...
# 2024-09-02    90.0
# 2022-09-03    93.0
# 2022-08-21    93.0
# 2024-11-24    78.0
# 2024-09-19    89.0
# Name: actual_max_temp, Length: 130, dtype: float64

# %%
open_m_test = X_ensemble_test['open_meteo_forecast']

hp.calculate_metrics(y_ensemble_test, open_m_test )
# Out:
# Mean Squared Error (MSE): 3.8598461538461537
# Mean Absolute Error (MAE): 1.575384615384615
# Root Mean Squared Error (RMSE): 1.9646491172334448
# (3.8598461538461537, 1.9646491172334448, 1.575384615384615)

# %%
rf_residuals = y_ensemble_test - ensemble_rf_predictions

std_rf_residuals = np.std(rf_residuals)
print(std_rf_residuals)


ensemble_y_test_windowed_s = ensemble_target_scaler.inverse_transform(ensemble_y_test_windowed)

lstm_residuals = ensemble_y_test_windowed_s - ensemble_target_scaler.inverse_transform(ensemble_lstm_y_pred)

std_lstm_residuals= np.std(lstm_residuals)
std_lstm_residuals
# Out:
# 1.303548145032748
# 1.4206195782322548
