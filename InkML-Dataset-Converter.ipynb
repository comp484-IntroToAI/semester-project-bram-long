# %% [markdown]
# # MathWriting Dataset
#
# This notebook contains code snippets showing how to read data from the MathWriting dataset, and do some minimal processing.
#
# Licensed under the Apache License, Version 2.0

# %%
import dataclasses
import json
import os
import pprint
import re

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpl_patches

from xml.etree import ElementTree

# %% [markdown]
# ## Download
#
# Download the data and unpack it.

# %%
# !wget -nc https://storage.googleapis.com/mathwriting_data/mathwriting-2024-excerpt.tgz
# !tar zxf mathwriting-2024-excerpt.tgz
# !ls mathwriting-2024-excerpt

import os
CURRENT_DIR = os.getcwd()
MATHWRITING_ROOT_DIR = os.path.join(CURRENT_DIR, './mathwriting-2024-excerpt')

# %%
# To use the full dataset, uncomment and run this cell instead of the one above.
#!wget -nc https://storage.googleapis.com/mathwriting_data/mathwriting-2024.tgz
#!tar zxf mathwriting-2024.tgz
#!ls mathwriting-2024
#MATHWRITING_ROOT_DIR='mathwriting-2024'

# %% [markdown]
# ## Reading InkML files
#
# All inks are provided in InkML format. The code below shows how to read the specific structure used by MathWriting.

# %%
@dataclasses.dataclass
class Ink:
  """Represents a single ink, as read from an InkML file."""
  # Every stroke in the ink.
  # Each stroke array has shape (3, number of points), where the first
  # dimensions are (x, y, timestamp), in that order.
  strokes: list[np.ndarray]
  # Metadata present in the InkML.
  annotations: dict[str, str]


def read_inkml_file(filename: str) -> Ink:
  """Simple reader for MathWriting's InkML files."""
  with open(filename, "r") as f:
    root = ElementTree.fromstring(f.read())

  strokes = []
  annotations = {}

  for element in root:
    tag_name = element.tag.removeprefix('{http://www.w3.org/2003/InkML}')
    if tag_name == 'annotation':
      annotations[element.attrib.get('type')] = element.text

    elif tag_name == 'trace':
      points = element.text.split(',')
      stroke_x, stroke_y, stroke_t = [], [], []
      for point in points:
        x, y, t = point.split(' ')
        stroke_x.append(float(x))
        stroke_y.append(float(y))
        stroke_t.append(float(t))
      strokes.append(np.array((stroke_x, stroke_y, stroke_t)))

  return Ink(strokes=strokes, annotations=annotations)


import matplotlib.pyplot as plt

def display_ink(
    ink: Ink,
    *,
    figsize: tuple[int, int]=(15, 10),
    linewidth: int=2,
    color=None,
    save_path: str = ""
):
    """Simple display for a single ink with option to save as PNG, without axes."""
    plt.figure(figsize=figsize)
    
    # Turn off the axis
    plt.axis('off')
    
    # Set the figure edge color to white (effectively removing the border)
    plt.gcf().patch.set_facecolor('white')
    
    for stroke in ink.strokes:
        plt.plot(stroke[0], stroke[1], linewidth=linewidth, color=color)
    
    # Invert y-axis (assuming this is still needed for correct orientation)
    plt.gca().invert_yaxis()
    
    # Ensure the aspect ratio is equal
    plt.gca().set_aspect('equal', adjustable='box')
    
    # Remove all the ticks
    plt.tick_params(axis='both', which='both', length=0)
    
    # Remove all the spines
    for spine in plt.gca().spines.values():
        spine.set_visible(False)
    
    # Adjust the plot to remove any padding
    plt.tight_layout(pad=0)
    
    if save_path:
        plt.savefig(save_path, format='png', bbox_inches='tight', pad_inches=0)
        print(f"Image saved as {save_path}")
    
    plt.show()

# %%
ink = read_inkml_file(os.path.join(MATHWRITING_ROOT_DIR, 'train', '060ab59eeba54d2f.inkml'))
save_dir = os.path.join(CURRENT_DIR, 'math-image-dataset/test-images/test.png')
display_ink(ink, color='black', save_path= save_dir)
# Out:
# Image saved as /Users/longtruong/Documents/GitHub/AI-Math-Solver/math-image-dataset/test-images/test.png

# %%
def process_folder(folder_path):
    """
    Iterate through all files in the given folder and process each file.
    """
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            print(file_path)
process_folder(MATHWRITING_ROOT_DIR)
# Out:
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/.DS_Store
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/readme.md
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols.jsonl
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic-bboxes.jsonl
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0005ea8e21185d36.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/017a79eea7fa5f63.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/009f7b727b467490.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00184588166a4dac.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00235ec3dee919dd.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/008f588f1c25ce16.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00ed2238753c9850.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0198a68035125b5a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00f546829c405447.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01a0415f932322d3.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/010963a06d1d5a79.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00c4f34b460c7933.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/011bc2c4d3e15714.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0068bc1f523b42d8.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/007a639f47c479d0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0155c0fe01231b04.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/002c168eb422aab9.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/006631d6baa51d31.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/007a46e2dd19428e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/008d3f60da3e972b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00245713d08b4f1a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/009183c575123315.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/003169384315282b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/018b8fb309ce7af2.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00b2a1efdeae0ced.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/018f48ac8fe4bd53.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0115ad5ee12ad7d4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00253e181f0200ab.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/006fb32b84a99137.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/017c4e5970880570.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01529aa0572f4897.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/012f1f23d40a2995.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0047f70eafca2534.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/002b6a98000765fb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01470b33b8c78f3f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/016af79ba8f2cca8.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00c94cb75d8df0bf.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/001f0f96215e2d84.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00f3fa64f4c2235f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0067440924b60b2b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/003921302c543b2c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/004466873ec97648.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/001f0c3d8940f546.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00e8bf4cde24f874.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00b2ce18a5aa30a6.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00e00364101abad0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/018fb881d2eef21d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01998b624db95830.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/013f565c7a547d0b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00000b332dcd6fe5.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/008004981b5b3ee1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01844e9baa82698c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01ab63ab784befeb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/019d0ab8b91ae217.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/012c517a05e2c2d4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00e6d1340b0b48b7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/000453d57c3d334d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0005d0be8e507b24.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/011a66ef71133c7d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00d3c94d3fc0dd27.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/006b9bfab1127fac.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00622d73c8739bd8.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01927fe0f1d3c23d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/016e9b0a2882071d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00ee5698f103452f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/018f456e217f1301.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00a32b900a4aa32f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0075591d8b2ba4d2.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/017b290258802288.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01054bf06792066a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0025484cf71c8ab7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0154666b7b559c17.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01a33dcbdaf5d858.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01a0b54b759ab60d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/018f8eb18419d5bb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0023e88388577dc1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0114d751a72fd56b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0040a950663bd899.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00061be0501a1fa8.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/009fc6849e2b7909.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0013be3abc070fb7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/013b7229b727f967.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0019bb8e97507f8e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/014be054e72e64fd.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00ac5cd85e462376.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/002651244bc93554.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/014d90d483380e66.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00c22b6f5407cf2d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00997a3afd226540.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0101e1e2b84d7837.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/012cebd6f0be97bb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/0178bf7cceb64473.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00a58f479a9d95b9.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01058e873802b3d2.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00b45d3bd1d56ead.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01992bb808919d17.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/00146a32fdab9e8e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01468b08b993df97.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/011f633d896bd07b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/valid/01a595d8d764a7b7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01b74db41e479782.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01cdd808862eab64.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02c39c1be9d660b7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0175c1fb5814dc11.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/028414d36ea98262.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/030a0f18b6fcb87b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0090db2a639b5c98.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01f3445177808c3d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/00db5331b85f4d47.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/004fc8d3f626f1d9.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0111fa141bb73b48.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/013a32b84ce6252f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/00ba90fe7f71d8c6.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0052b8e13b5f4a36.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/001083e26028da36.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0114e881d8b22bbb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01e6c79f4d27bc54.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/003ca9082c7047d3.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/030373f9d3edac3b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02ace78dfc726867.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0204f1101b3f4033.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/015e012d8baa97f3.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02b7060b95d998eb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0083f66ddd05c46c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01a2f3186b7e33e1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01d2b56291c7ffdd.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/030ea5646116a251.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01d90fce29b20f64.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/00eaf4f2d3d20bb1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/006badbfc63bbd21.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02dcdb815d18cdf1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/00692074bbc0f678.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/00386113d577085b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/011f1f41eb55b661.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/00fcddfee1ebfee6.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02c9daf282f5a1e3.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01e4c8973307a964.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0121d7fdad59c8ab.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01d12458811a5a38.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/029b5da0999d4903.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02d5b5f98ac5fbd2.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/026fd85034106735.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01292cf19c2c9c7c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/004c9413be3ff1be.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0272a794109d5d2d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0017bb5822bcba69.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/00d4fc6636cbf2d9.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02da6f52e30f674d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01c37bbe7ea55c56.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01cf085d26abe325.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/016a39f81ff20b8d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/002ae6d5dd4173e4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/00915f0ffe17930e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/010d0f9e951a7a44.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01917677eaf160bb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/00c46c9b07b39bb7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01b552b8a037ab13.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/000a4e8ca49c5a1c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/014f7412fa06f5c0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0276c02c9b9222e9.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0199f657babdf636.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/028cf1f0507df703.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/023a443f36a838ff.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/029decc2d74fd082.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02aced0c052805c6.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01d4d9a9dc145333.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/032278982233fefa.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0325d90612c71772.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02248037ee4a5528.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/032360b882783120.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01d54b93c127e89c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01859fc130dc9008.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01a53ae1e3a9b918.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02b1dc6d4efd493a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0333d9584ff7c0d0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02657f6bba1d2004.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/009fb93aab47d6f5.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0180366e774d93be.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0247a5d7e1002d66.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0255dc5b14261907.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02894b4ff1ee6c7b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/03277de2f80a8aaf.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02c6f6dea91a2a06.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01453872d3d2afe5.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/010d4fea2361f01f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02720f6a67e8bc09.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/00ad7566b9f1d872.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01752f0f5fba0225.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/022b4cfb5a5a3856.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/025f51bee0e59494.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/02de91b624143438.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/00fee560e6c9af79.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01ab618a2350036f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/01d2f97f90ed79e6.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/022be26e0a8ab535.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0235a447c15a24d7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/009d124a50399bba.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0082d4aa943b9f8c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/0316d949cd776194.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/test/024279a4b8037bae.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00009cc521976274.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000bbf477610dad5.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0002aa1c9c2b291e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0004f177e981e3ae.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000a48db4e4d6adc.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000cff6e9b8d4939.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000e45dc2fdce340.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0000cbeca361b986.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000440fb7f5d3094.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0009a534d839ffef.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00083308cce64627.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00060721c2add647.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000eb731bc645751.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0006c633e31cb23a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000a192d6e72d170.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0001e735aa74f8bc.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000a981b892ab8d1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00006210bcd6c975.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0005e13622983f76.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000d6170688670d0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000cc63ea16feb7c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00032092410c1677.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0004597d0d1b430f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000738d0afa0adb1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000918f80b681a7a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000269ab4b30fcb0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00040c7f0ccce622.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0007c0cc361ef700.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00062ab9cb5926f2.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0007b4476b305063.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000e33646eb22a80.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0001721306e6f1df.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0005ccb2789b30f8.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0007c32e1880c9a4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0009a349d9752e67.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0000e31e33be1430.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000ef5e38715a9bc.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0007fad189c59cf8.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000bc7ee546680fe.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0000d71cda4329a6.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00070574bf81e8f6.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0002407f992e8307.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000bec6751692179.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00094d55c6b7cf9e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0005ec27f7221a95.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000d657eba4141ca.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0002683ca298b741.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0000d72d6d24c485.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0003edb353f2f110.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0004bce586182a21.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00078ec9bfbf96e3.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000bc1ef3c3ee9aa.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0009e82c62c2aaf4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000953b97f720153.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000bed2d2f2e43d8.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000d8f307d81395e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000b80a1a1f5a854.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000cd9b275fc6016.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000dd1d7b7d9ea40.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00029f64ce4df82b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0005d575fc3397cb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00062af9cb5101f5.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000a259db55c92df.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000cddcb51302ae2.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0009005ebfd6abaa.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00032e42d3968c35.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00098463d5ada4bd.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00015681597577ca.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000133c1b3a5739e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000b9a9b2f830aa9.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000231fcc0808b6a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000b7c3278aa77bf.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0002459d7b2998f7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0008be2f445b2bfb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000dbc279ea73041.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0001d203bdf3b07e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000da0e972a64830.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0009b02280fd14c0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0006d70f6ba76817.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000ec7031be06d31.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0005f2bd440af609.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00003a22b704282e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000e643a429dba48.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000a5eb4dbb0a626.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0003f2b706b94e79.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0002f466c11dda20.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00026ea02bde7a04.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00049d9271209efb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00097e7e3c9f1f9b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00037f1a6f22b509.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000a7a5a694616a5.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0007766d3234cdbc.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0000baa17488cf00.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00000e2b2e813760.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0000ec54f84b729e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000e15155cba9feb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0005bd3dd973f475.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/0001e24e0cc47752.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/00031fd3a9bbd70f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/synthetic/000b905c653fd48d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/050f08e2fe6fe162.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/04e56f2e30f866d8.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/049aa166f1cfb206.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/076e7b58bfaba0f1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/04852f06a82865c1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/03474b3d9a7ae87b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/05373ec225cc541a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0656e77f512563c5.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0443cdf212ee67b1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/02c82a919e114b86.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/004970a2ad0fcb27.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/03d01506fe3647c4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0053f4751a1d9065.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/073036bdd616605d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/06b2711e539715e0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/00bddacfb3de33ce.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/067a327b0c92095f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/060ab59eeba54d2f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/00874649f83c08b3.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/02a7f7f172671fb4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/068de3aad90c403c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0050464363a7d02d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/05fa73b7807336c8.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/049d2cf3f10ac2d7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/04a855ef776363c2.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0435a7e82431e973.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/02210ec4545e3b0a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/01d4ae95eb9e94c8.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0368471ca4fbe892.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/038ccb46ae3443db.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0698cd5349dae70c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/00bc1c89dff0672e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0667cabda0ae2b81.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/07556e5288679e40.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/01f2f6142ec1c97f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/051a9b215ce2f7dc.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0417ce94315c0dea.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/00c0cefd35f09179.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/018cd2d904174062.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/04f65fb089280e4c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0426225e4adc4605.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/00e206f3a5cdc7fb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/03bd51165a1a81b1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0668dd347d600906.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/01d4536a52886b73.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/04f16ee0cbb55791.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/05f2be02bbe36bd4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0326c8496e189144.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/032e674bf4a61ff0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/07534c098d424d5f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/028a59322b50b764.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/050eb35c2f18a695.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/021aff768b53ac50.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/04fc9a7665035a0d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/01650d074915628e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/01a043f03146f76c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/06a81979619c88e4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/02229a0c174d8dbe.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/04e2d85cba0103e9.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/04fc707abea3e7a1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/059ac88233086bc0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/032130fddec53c78.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/020ebba0c00073be.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0606da46464a5804.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0112074a000acff4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/000aa4c444cba3f2.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/025f579aa67dfd7c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/07549352bfb72996.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/04026cefc5bee356.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/03d92e3e170bb629.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/070c12a71a7265a3.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/02f72a386327c6d9.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/02f5816611877c27.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/046728735864246f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/03af7845cfbbde59.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0491ecbb62f31a6e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0578f6b97d18358a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/06186bea537734a2.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0703652c7a0c26f7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/033d57e0703ab948.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/063aa42f5d0ef5be.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/033bbf63000c086d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/04aeed012ef93461.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/046fde10ad80f6f4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/01fdfab60060594b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/06c6f0395cdee938.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/032cab7514e408ba.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/02270559509706de.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/047ce2586c0b5f0c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/05c704f21b802507.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/07406a1470c708c4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/010c427bf30599d3.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/01751ea13ceb1817.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/0717c14705cc721d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/03c3977784c8f56c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/005f0a6b379cc5db.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/059225965e1e5dd6.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/05882db6930f636c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/076be7470d48f458.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/train/01e8ffa2afd3ae8e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03a7242fe6f68f44.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02a62549ac865354.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/01b9d59472450b2b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0254dc96046f7c35.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/025e64f4f02b9d43.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/000e859b63b7d06e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03e5580a786e700e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/039da9abdee1f7a9.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/025a8d2418de6a4f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0128241046fec7b7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0005e477f85ab99f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03b6e7188336f25a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0259d024758dd91f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0088230a29c95c4c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03d12adeb87369a5.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/01559e8afc4137d0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0284bf70aaa33511.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/046189e4c668dd2f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02c3a6a126b713c4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03c185d42af95e95.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02f591728d0bd4f9.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/040eb4879c95c04c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0344998cc2a592ac.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/04549d011bc31b24.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02b471f766d965a1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02fa953530d762fc.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03f63a60f419972d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/033e4a3693b95cf3.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02d228d27e479f00.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/00c63417d1821a8c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02a5e119c2606113.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03a15f81b4fd2ba7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0069933b924e534e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02b49e294144c958.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/022bea7f2a38e690.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/012994d2a88b84a4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0443bfd082dfb224.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02a2f5042240d12f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/00c8739028708429.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0333ad86fc75e190.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02b641d9862ab2e5.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02f994af0454c495.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/039f7a193fc165cd.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03e2a25b3fd97391.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/002d5789212ff5df.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/00d93e984cb8b2d5.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0109da9e9566d74a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0405148ac6639b60.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/011cf5d65bd57083.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03a293ada3bd8d52.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/010b76fd723a3af2.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/021087f7047f5a00.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02e93c6fc6b99473.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03ccfa2dc4dfdbba.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0319c12536eae709.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03389b8a95d13017.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/00a831c56aa243ce.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02b0157033af59bf.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/00c4f00d4aad7ee4.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/002548066bdfb58d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/01db722d470c211e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02a2c577fea485a7.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/04006e204d1fb109.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/00c0af89f6128b01.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/00364596a5f9045f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0323783e72df4ee5.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/003d8a8535a7876c.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03c090aebf755ef3.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/01630f1308be800d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/039ef93f476a4d31.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0188824a46c2c28a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02b7e36f1cb40312.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/04351682ae7aa7ec.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/040de51e61c17ddb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02c823b6ac86a9d1.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/045aa5c68f18b3a0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/04352de48b49a66a.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/000a44269f71169e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02ac51e03ff6783e.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02c7f14e6b0c98be.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/01b947ea04229c50.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0030215e665a83cb.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03b21e40fa35845d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02482636093fcfb0.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/016eceed5d406c2b.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/00ec3d5c791e6a43.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/00af9f69174396d2.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02349d207ba66622.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/01adcfe95157fa20.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/003fc1233106a589.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/024aa54d9b89f58f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/013433c6b018d0e2.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/01af37ae5920cb45.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02f5f2ffd38ac01d.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02abc2da43ba8b9f.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/0103cc497db8aca5.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/03192e0226ad9cd9.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/02aa3ae265d99e81.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/016603a4b4b80d28.inkml
# /Users/longtruong/Documents/GitHub/AI-Math-Solver/./mathwriting-2024-excerpt/symbols/00a11cdf8d773ca3.inkml

# %% [markdown]
# ## Reading Bounding Box Files
#
# These files contain bounding boxes with the symbol that should be displayed in it, plus the LaTeX string for the overall expression. The format used is JSONL: each line in the file is a separate JSON object containing all the bounding boxes for a single mathematical expression.
#
# The code below shows how to turn each of these lines into a Python class.

# %%
@dataclasses.dataclass
class BoundingBox:
  """A bounding box for a single symbol."""
  # The symbol that should appear in the bounding box, in LaTeX notation.
  token: str
  # Definition of the bounding box.
  x_min: float
  y_min: float
  x_max: float
  y_max: float


@dataclasses.dataclass
class BoundingBoxes:
  """A set of bounding boxes for a complete mathematical expression."""
  # The complete (raw) LaTeX string.
  label: str
  # A normalized version of `label`.
  normalized_label: str|None
  # Bounding boxes for all symbols in the expression, in no particular order.
  bboxes: list[BoundingBox]


def read_bbox_file(filename: str, *, index: int=0) -> BoundingBoxes:
  """Reads a single bounding box from the input file."""
  with open(filename, "r") as f:
    for n, line in enumerate(f):
      if n < index:
        continue

      bboxes = json.loads(line)

      symbol_bboxes = []
      for bbox in bboxes['bboxes']:
        symbol_bboxes.append(BoundingBox(
            token=bbox['token'],
            x_min=bbox['xMin'],
            y_min=bbox['yMin'],
            x_max=bbox['xMax'],
            y_max=bbox['yMax']))

      return BoundingBoxes(
              label=bboxes['label'],
              normalized_label=bboxes.get('normalizedLabel', None),
              bboxes = symbol_bboxes)


def display_bboxes(bboxes: BoundingBoxes, *, figsize: tuple[int, int]=(15, 10)):
  """Displays a set of bounding boxes for debugging purposes."""
  fig = pl.figure(figsize=figsize)
  ax = fig.gca()
  x_min = float('inf')
  y_min = float('inf')
  x_max = -float('inf')
  y_max = -float('inf')
  for bbox in bboxes.bboxes:
    x_min = min(x_min, bbox.x_min)
    y_min = min(y_min, bbox.y_min)
    x_max = max(x_max, bbox.x_max)
    y_max = max(y_max, bbox.y_max)

    ax.add_patch(
        mpl_patches.Polygon(
            ((bbox.x_min,bbox.y_min),
            (bbox.x_min,bbox.y_max),
            (bbox.x_max,bbox.y_max),
            (bbox.x_max, bbox.y_min)),
            closed=True,
            facecolor='none',
            edgecolor='darkblue',
            linewidth=2))

  width = x_max - x_min
  height = y_max - y_min

  # We put the text in one go at the end to be able to scale it properly.
  for bbox in bboxes.bboxes:
    box_width = bbox.x_max - bbox.x_min
    box_height = bbox.y_max - bbox.y_min
    if bbox.token != r'\frac':
      ax.text(bbox.x_min+box_width/2,
              bbox.y_min+box_height/2,
              bbox.token,
              verticalalignment='center',
              horizontalalignment='center',
              fontsize=100000 / max(width, height))

  margin_ratio = 0.1
  ax.set_xlim(x_min-margin_ratio*width, x_max+margin_ratio*width)
  ax.set_ylim(y_max+margin_ratio*height, y_min-margin_ratio*height)
  pl.title(bboxes.normalized_label or bboxes.label)

# %%
bboxes = read_bbox_file(
    os.path.join(MATHWRITING_ROOT_DIR, 'synthetic-bboxes.jsonl'),
    index=2)
display_bboxes(bboxes)

# %% [markdown]
# ## Extracting Individual Symbols
#
# For the purpose of synthesizing inks from bounding boxes, isolated symbols are provided as inks. These were extracted from inks from the training set, and MathWriting contains all the information necessary to recompute this extraction.
# The code below shows how to do it.

# %%
@dataclasses.dataclass
class InkPart:
  """A pointer to a part of an ink corresponding to a single symbol."""
  # Which sample the symbol is from. Ex: '00016221aae38d32'
  source_sample_id: str
  # Which symbol it is. Ex: '\sum'
  label: str
  # Indices of strokes in the source ink that cover the symbol.
  stroke_indices: list[int]


def read_symbols_file(filename: str) -> list[InkPart]:
  """Reads all the symbol definitions."""
  symbols = []
  with open(filename, "r") as f:
    for line in f:
      symbol_json = json.loads(line)
      symbols.append(InkPart(
          source_sample_id=symbol_json['sourceSampleId'],
          label=symbol_json['label'],
          stroke_indices=symbol_json['strokeIndices']))
  return symbols


def get_symbol_ink(symbol: InkPart) -> Ink:
  """Computes the actual ink from an InkPart object."""
  ink = read_inkml_file(
      os.path.join(MATHWRITING_ROOT_DIR, "train", f"{symbol.source_sample_id}.inkml"))
  strokes = [ink.strokes[i] for i in symbol.stroke_indices]
  return Ink(
      strokes=strokes,
      annotations={
          'label': symbol.label,
          'splitTagOriginal': ink.annotations['splitTagOriginal']})

# %%
# Extract one isolated symbol and display it.
symbols = read_symbols_file(os.path.join(MATHWRITING_ROOT_DIR, 'symbols.jsonl'))
symbol_ink = get_symbol_ink(symbols[3902])
display_ink(symbol_ink, color='black')

# %% [markdown]
# ## Ink Rasterization
#
# This shows how to use Cairo for high-quality rendering of inks.

# %%
# !apt-get install libcairo2-dev libjpeg-dev libgif-dev
# !pip install pycairo

# %%
import cairo
import math
import PIL
import PIL.Image


def cairo_to_pil(surface: cairo.ImageSurface) -> PIL.Image.Image:
  """Converts a ARGB Cairo surface into an RGB PIL image."""
  size = (surface.get_width(), surface.get_height())
  stride = surface.get_stride()
  with surface.get_data() as memory:
    return PIL.Image.frombuffer(
        'RGB', size, memory.tobytes(), 'raw', 'BGRX', stride
    )


def render_ink(
    ink: Ink,
    *,
    margin: int = 10,
    stroke_width: float = 1.5,
    stroke_color: tuple[float, float, float] = (0.0, 0.0, 0.0),
    background_color: tuple[float, float, float] = (1.0, 1.0, 1.0),
) -> PIL.Image.Image:
  """Renders an ink as a PIL image using Cairo.

  The image size is chosen to fit the entire ink while having one pixel per
  InkML unit.

  Args:
    margin: size of the blank margin around the image (pixels)
    stroke_width: width of each stroke (pixels)
    stroke_color: color to paint the strokes with
    background_color: color to fill the background with

  Returns:
    Rendered ink, as a PIL image.
  """

  # Compute transformation to fit the ink in the image.
  xmin, ymin = np.vstack([stroke[:2].min(axis=1) for stroke in ink.strokes]).min(axis=0)
  xmax, ymax = np.vstack([stroke[:2].max(axis=1) for stroke in ink.strokes]).max(axis=0)
  width = int(xmax - xmin + 2*margin)
  height = int(ymax - ymin + 2*margin)

  shift_x = - xmin + margin
  shift_y = - ymin + margin

  def apply_transform(ink_x: float, ink_y: float):
    return ink_x + shift_x, ink_y + shift_y

  # Create the canvas with the background color
  surface = cairo.ImageSurface(cairo.FORMAT_ARGB32, width, height)
  ctx = cairo.Context(surface)
  ctx.set_source_rgb(*background_color)
  ctx.paint()

  # Set pen parameters
  ctx.set_source_rgb(*stroke_color)
  ctx.set_line_width(stroke_width)
  ctx.set_line_cap(cairo.LineCap.ROUND)
  ctx.set_line_join(cairo.LineJoin.ROUND)

  for stroke in ink.strokes:
    if len(stroke[0]) == 1:
      # For isolated points we just draw a filled disk with a diameter equal
      # to the line width.
      x, y = apply_transform(stroke[0, 0], stroke[1, 0])
      ctx.arc(x, y, stroke_width / 2, 0, 2 * math.pi)
      ctx.fill()

    else:
      ctx.move_to(*apply_transform(stroke[0,0], stroke[1,0]))

      for ink_x, ink_y in stroke[:2, 1:].T:
        ctx.line_to(*apply_transform(ink_x, ink_y))
      ctx.stroke()

  return cairo_to_pil(surface)

ink = read_inkml_file(os.path.join(MATHWRITING_ROOT_DIR, 'train', '0668dd347d600906.inkml'))

# %%
render_ink(ink)

# %%
render_ink(
    ink,
    stroke_width=5.0,
    stroke_color=(.8, .1, .1),
    background_color=(.96, .96, .86),
  )

# %% [markdown]
# ## Model Evaluation
#
# A few functions to compute the character error rate for model performance evaluation.

# %% [markdown]
# ### Tokenizer
#
# Function to split a LaTeX expressions into tokens. These tokens can be used for model training or model evaluation.

# %%
_COMMAND_RE = re.compile(r'\\(mathbb{[a-zA-Z]}|begin{[a-z]+}|end{[a-z]+}|operatorname\*|[a-zA-Z]+|.)')


def tokenize_expression(s: str) -> list[str]:
  r"""Transform a Latex math string into a list of tokens.

  Tokens are strings that are meaningful in the context of Latex
  e.g. '1', r'\alpha', r'\frac'.

  Args:
    s: unicode input string (ex: r"\frac{1}{2}")

  Returns:
    tokens: list of tokens as unicode strings.
  """
  tokens = []
  while s:
    if s[0] == '\\':
      tokens.append(_COMMAND_RE.match(s).group(0))
    else:
      tokens.append(s[0])

    s = s[len(tokens[-1]) :]

  return tokens


# Example
print(tokenize_expression(r'\frac{\alpha}{2}\begin{matrix}1&0\\0&1\end{matrix}\not\in\mathbb{R}'))

# %% [markdown]
# ### CER Computation
#
# Computation of the Character Error Rate.

# %%
# !pip install jiwer
import jiwer

# %%
def compute_cer(truth_and_output: list[tuple[str, str]]):
  """Computes CER given pairs of ground truth and model output."""
  class TokenizeTransform(jiwer.transforms.AbstractTransform):
    def process_string(self, s: str):
      return tokenize_expression(r'{}'.format(s))

    def process_list(self, tokens: list[str]):
      return [self.process_string(token) for token in tokens]

  ground_truth, model_output = zip(*truth_and_output)

  return jiwer.cer(truth=list(ground_truth),
            hypothesis=list(model_output),
            reference_transform=TokenizeTransform(),
            hypothesis_transform=TokenizeTransform(),
      )

# %%
# Test data to run compute_cer().
# The first element is the model prediction, the second the ground truth.
examples = [
    (r'\sqrt{2}', r'\sqrt{2}'),  # 0 mistakes, 4 tokens
    (r'\frac{1}{2}', r'\frac{i}{2}'),  # 1 mistake, 7 tokens
    (r'\alpha^{2}', 'a^{2}'),  # 1 mistake, 5 tokens
    ('abc', 'def'),  # 3 mistakes, 3 tokens
]

# 5 mistakes for 19 tokens: 26.3% error rate.
print(f"{compute_cer(examples)*100:.1f} %")
